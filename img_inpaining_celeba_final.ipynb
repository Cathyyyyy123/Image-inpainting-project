# %% [markdown]
# # **Importing Libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torchvision
import torchvision.transforms as transforms 
import torch.nn as nn  
import torch.nn.functional as F
import torch.optim as optim
from torchvision import models
import copy
import cv2
from PIL import Image
import os
import random

# %% [markdown]
# # **Data Visualization**

# %%
USE_GPU = True

dtype = torch.float32 # we will be using float throughout this tutorial

if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

print('using device:', device)
# Out:
# using device: cuda

# %%
transform_train = transforms.Compose([transforms.ToTensor(),
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                                      transforms.Resize(size = (256,256)),
])

transform_test = transforms.Compose([transforms.ToTensor(),
                                      transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
                                      transforms.Resize(size = (256,256)),
])

# %%
trainset = torchvision.datasets.CelebA(root = './data', split='train', download = True, transform = transform_train)
testset = torchvision.datasets.CelebA(root = './data', split='test', download = True, transform = transform_test)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print(trainset)
# Out:
# Dataset CelebA
#     Number of datapoints: 162770
#     Root location: ./data
#     Target type: ['attr']
#     Split: train
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#                Resize(size=(256, 256), interpolation=bilinear, max_size=None, antialias=True)
#            )

# %%
print(testset)
# Out:
# Dataset CelebA
#     Number of datapoints: 19962
#     Root location: ./data
#     Target type: ['attr']
#     Split: test
#     StandardTransform
# Transform: Compose(
#                ToTensor()
#                Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#                Resize(size=(256, 256), interpolation=bilinear, max_size=None, antialias=True)
#            )

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size=4, shuffle=True)

# %%
print(len(trainloader))
# Out:
# 40693

# %%
dataiter = iter(trainloader)
images , labels = next(dataiter)

print(images.shape)

print(images[1].shape)
# Out:
# torch.Size([4, 3, 256, 256])
# torch.Size([3, 256, 256])

# %%
img = images[1]
print(type(img))
# Out:
# <class 'torch.Tensor'>

# %%
npimg = img.numpy()
print(npimg.shape)
npimg = np.transpose(npimg, (1,2,0))
print(npimg.shape)
# Out:
# (3, 256, 256)
# (256, 256, 3)

# %%
batch_size = 4

# %%
def imshow(img, title):
  npimg = img.numpy() / 2 + 0.5
  plt.figure(figsize = (batch_size, 1))
  plt.axis('off')
  plt.imshow(np.transpose(npimg, (1,2,0)))
  plt.title(title)
  plt.show()

# %%
plt.figure(figsize = (1,1))
plt.imshow(npimg)
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def show_batch_images(dataloader):
  images, labels = next(iter(dataloader))
  img = torchvision.utils.make_grid(images)
  imshow(img, title = 'Images')

# %%
for i in range(4):
  show_batch_images(trainloader)

torch.cuda.empty_cache()

# %% [markdown]
# # **Data Pre Proccessing**

# %%
image_dims = (128, 128)
batch_size = 32
subset_size = 6400
subset_size_test = 320

# %%
def imshow_masked(img):
  npimg = img.numpy()
  plt.figure(figsize = (3, 3))
  plt.axis('off')
  plt.imshow(np.transpose(npimg, (1,2,0)))
  plt.show()

# %%
def add_gaussian_noise(image, mean=0, sigma=0.05):
    """
    Adds Gaussian noise to an image.
    - mean: Mean of the Gaussian noise
    - sigma: Standard deviation of the Gaussian noise
    """
    noise = torch.randn_like(image) * sigma + mean
    return image + noise

# %%
from torch.utils.data import Subset

class Dataset(torch.utils.data.Dataset):
    def __init__(self, path, image_dims=(64, 64), n_channels=3, split='train', subset_size=None):
        celeba_dataset = torchvision.datasets.CelebA(root=path, split=split, download=True)
        
        # If subset_size is provided, create a subset of the dataset
        if subset_size is not None:
            subset_indices = torch.randperm(len(celeba_dataset))[:subset_size]
            celeba_dataset = Subset(celeba_dataset, subset_indices)
        
        self.dataset = celeba_dataset
        self.image_dims = image_dims
        self.n_channels = n_channels
        self.resize = transforms.Resize(image_dims)
        self.to_tensor = transforms.ToTensor()

    def __getitem__(self, index):
        image, label = self.dataset[index]

        Y_output = self.resize(image)
        X_input, X_mask = self.Create_Mask(Y_output)
        return self.to_tensor(X_input), self.to_tensor(X_mask), self.to_tensor(Y_output)

    def __len__(self):
        return len(self.dataset)

    def Create_Mask(self, image):
        mask = np.full((self.image_dims[0], self.image_dims[1], self.n_channels), 255, dtype=np.uint8)

        for _ in range(np.random.randint(5, 10)):
            x1, x2 = np.random.randint(1, self.image_dims[0]), np.random.randint(1, self.image_dims[0])
            y1, y2 = np.random.randint(1, self.image_dims[1]), np.random.randint(1, self.image_dims[1])
            thickness = np.random.randint(self.image_dims[0]/64*2, self.image_dims[0]/64*4)

            cv2.line(mask, (x1, y1), (x2, y2), (1, 1, 1), thickness)

        image = np.asarray(image)
        masked_image = cv2.bitwise_and(image, mask)
        return masked_image, mask

# %%
Trainset = Dataset('./data', image_dims, subset_size=subset_size)
Testset = Dataset('./data', image_dims, split='test', subset_size=subset_size_test)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
Trainloader = torch.utils.data.DataLoader(Trainset, batch_size = batch_size, shuffle = True)
Testloader = torch.utils.data.DataLoader(Testset, batch_size = batch_size, shuffle = False)

print(len(Trainloader))
print(len(Testloader))
# Out:
# 200
# 10

# %%
Train_dataiter = iter(Trainloader)
Test_dataiter = iter(Testloader)

# %%
X_in, X_mask, Y_out = next(Train_dataiter)
print(X_in.shape, X_mask.shape, Y_out.shape)
# Out:
# torch.Size([32, 3, 128, 128]) torch.Size([32, 3, 128, 128]) torch.Size([32, 3, 128, 128])

# %%
print('Masked Image')
imshow_masked(torchvision.utils.make_grid(X_in))
print('Masking Pattern')
imshow_masked(torchvision.utils.make_grid(X_mask))
print('Original Image')
imshow_masked(torchvision.utils.make_grid(Y_out))
# Out:
# Masked Image
# Masking Pattern
# Original Image

# %% [markdown]
# # **Training**

# %%
class PartialConv(nn.Module):
    """
    Implements a partial convolution layer, which only considers valid pixels in the convolution operation.
    This is particularly useful for tasks like inpainting where the input image may have missing values.
    """
    def __init__(self, in_filters, out_filters, kernel_size, strides=1, padding=0, dilation=1, groups=1, bias=True):
        super(PartialConv, self).__init__()
        
        # Calculate padding based on the kernel size to ensure the output size is the same as the input size
        padding = (kernel_size[0] // 2, kernel_size[1] // 2)
        self.input_conv = nn.Conv2d(in_filters, out_filters, kernel_size, strides, padding, bias=bias)
        
        # Convolution for mask with weights initialized to 1 and set to not require gradients
        self.mask_conv = nn.Conv2d(in_filters, out_filters, kernel_size, strides, padding, bias=False)
        
        # Constant value for normalizing the mask
        self.window_size = kernel_size[0] * kernel_size[1]
        
        # Initialize mask convolution weights to 1
        nn.init.constant_(self.mask_conv.weight, 1.0)
        
        # Freeze the mask convolution weights
        for param in self.mask_conv.parameters():
            param.requires_grad = False

    def forward(self, input, mask):
        """
        Forward pass of the partial convolution layer.
        
        Parameters:
        - input: The input image.
        - mask: A binary mask indicating which pixels are valid (1) and which are missing (0).
        
        Returns:
        - output: The convolved image, adjusted for valid pixel coverage.
        - output_mask: The updated mask after convolution.
        """
        output = self.input_conv(input * mask)
        
        # Add bias if present, reshaped to match output dimensions
        if self.input_conv.bias is not None:
            output_bias = self.input_conv.bias.view(1, -1, 1, 1).expand_as(output)
        else:
            output_bias = torch.zeros_like(output)

        with torch.no_grad():
            output_mask = self.mask_conv(mask)
            
        # Calculate mask ratio to adjust the convolution output based on the coverage of valid pixels
        mask_ratio = self.window_size / (output_mask + 1e-8)

        output_mask = torch.clamp(output_mask, 0, 1)
  
        mask_ratio = mask_ratio * output_mask
    
        # Adjust output based on valid pixel coverage and add bias
        output = output * mask_ratio
        output = output + output_bias

        return output, output_mask

# %%
class EncoderLayer(nn.Module):
    """
    Encoder layer used in the inpainting model, consisting of two partial 
    convolution layers followed by batch normalization and ReLU activation.
    """
    def __init__(self, in_filters, out_filters):
        super(EncoderLayer, self).__init__()
        self.p_conv_1 = PartialConv(in_filters, out_filters, (3, 3), strides=1)
        self.bn_1 = nn.BatchNorm2d(out_filters)
        self.act_1 = nn.ReLU()
        self.p_conv_2 = PartialConv(out_filters, out_filters, (3, 3), strides=2)
        self.bn_2 = nn.BatchNorm2d(out_filters)
        self.act_2 = nn.ReLU()

    def forward(self, inputs, masks):
        """
        Forward pass of the encoder layer, applying two sequential partial convolutions to both inputs and masks.
        
        Parameters:
        - inputs: The input image.
        - masks: The corresponding binary masks.
        
        Returns:
        - A tuple of convolved images and updated masks after each convolution layer.
        """
        conv_out_1, mask_out_1 = self.p_conv_1(inputs, masks)
        conv_out_1 = self.act_1(self.bn_1(conv_out_1))

        conv_out_2, mask_out_2 = self.p_conv_2(conv_out_1, mask_out_1)
        conv_out_2 = self.act_2(self.bn_2(conv_out_2))

        return conv_out_1, mask_out_1, conv_out_2, mask_out_2

# %%
class DecoderLayer(nn.Module):
    """
    Decoder layer for the inpainting model, which upsamples the input features 
    and combines them with features from the skip connections, followed 
    by partial convolutions to refine the features for accurate image reconstruction.
    """
    def __init__(self, in_filters_1, in_filters_2):
        super(DecoderLayer, self).__init__()
        
        # Upsample the image and mask to the higher resolution
        self.up_image = nn.Upsample(scale_factor=(2, 2))
        self.up_mask = nn.Upsample(scale_factor=(2, 2))
        
        self.p_conv_1 = PartialConv(in_filters_1 * 2, in_filters_1, (3, 3))
        self.bn_1 = nn.BatchNorm2d(in_filters_1)
        self.act_1 = nn.LeakyReLU(negative_slope=0.2)

        self.p_conv_2 = PartialConv(in_filters_1, in_filters_2, (3, 3))
        self.bn_2 = nn.BatchNorm2d(in_filters_2)
        self.act_2 = nn.LeakyReLU(negative_slope=0.2)

    def forward(self, in_image, in_mask, share_image, share_mask):
        """
        Forward pass of the decoder layer.

        Parameters:
        - in_image: The image features from the previous decoder layer.
        - in_mask: The mask from the previous decoder layer.
        - share_image: The corresponding image features from the encoder layer (skip connection).
        - share_mask: The corresponding mask from the encoder layer (skip connection).

        Returns:
        - A tuple of the convolved images and updated masks after each partial convolution layer.
        """
        up_out = self.up_image(in_image)
        mask_out = self.up_mask(in_mask)
        
        # Concatenate the upsampled features with the features from the skip connection
        concat_image = torch.cat([share_image, up_out], axis=1)
        concat_mask = torch.cat([share_mask, mask_out], axis=1)

        conv_out_1, mask_out_1 = self.p_conv_1(concat_image, concat_mask)
        conv_out_1 = self.act_1(self.bn_1(conv_out_1))
    
        conv_out_2, mask_out_2 = self.p_conv_2(conv_out_1, mask_out_1)
        conv_out_2 = self.act_2(self.bn_2(conv_out_2))

        return conv_out_1, mask_out_1, conv_out_2, mask_out_2

# %%
class InpaintingModel(nn.Module):
    def __init__(self, input_dims=(64, 64), num_channels=3):
        super(InpaintingModel, self).__init__()

        self.encoder_1 = EncoderLayer(num_channels, 32)
        self.encoder_2 = EncoderLayer(32, 64)
        self.encoder_3 = EncoderLayer(64, 128)
        self.encoder_4 = EncoderLayer(128, 256)

        self.decoder_1 = DecoderLayer(256, 128)
        self.decoder_2 = DecoderLayer(128, 64)
        self.decoder_3 = DecoderLayer(64, 32)
        self.decoder_4 = DecoderLayer(32, 3)

        self.output_layer = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(64, 128, kernel_size=5, padding=2),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(128, 256, kernel_size=5, padding=2),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True), 

            nn.Conv2d(256, 3, kernel_size=5, padding=2),
            nn.Sigmoid()
        )

    def forward(self, inputs, masks):
        conv_out_1, mask_out_1, conv_out_2, mask_out_2 = self.encoder_1(inputs, masks)
        conv_out_3, mask_out_3, conv_out_4, mask_out_4 = self.encoder_2(conv_out_2, mask_out_2)
        conv_out_5, mask_out_5, conv_out_6, mask_out_6 = self.encoder_3(conv_out_4, mask_out_4)
        conv_out_7, mask_out_7, conv_out_8, mask_out_8 = self.encoder_4(conv_out_6, mask_out_6)

        _, _, _, _ = self.decoder_1(conv_out_8, mask_out_8, conv_out_7, mask_out_7)
        _, _, _, _ = self.decoder_2(conv_out_6, mask_out_6, conv_out_5, mask_out_5)
        _, _, _, _ = self.decoder_3(conv_out_4, mask_out_4, conv_out_3, mask_out_3)
        _, _, conv_out_16, _ = self.decoder_4(conv_out_2, mask_out_2, conv_out_1, mask_out_1)

        outputs = self.output_layer(conv_out_16)
        return outputs

# %%
def jaccard_coeff(dataloader):
  for (X_input, X_mask, Y_output) in dataloader:
    X_input, X_mask, Y_output = X_input.to(device), X_mask.to(device), Y_output.to(device)
    outputs = model(X_input, X_mask)
    eps = 1e-15
    outputs = outputs.view(-1)
    Y_output = Y_output.view(-1)
    intersection = (outputs * Y_output).sum()
    union = (outputs.sum() + Y_output.sum()) - intersection
  return (intersection / (union + eps))

# %%
from torchvision.models import vgg16
class CombinedLoss(torch.nn.Module):
    def __init__(self):
        super(CombinedLoss, self).__init__()
        self.mse_loss = torch.nn.MSELoss()
        self.vgg = vgg16(weights=True).features[:23]  # Using the first few layers of VGG16 for perceptual loss
        for param in self.vgg.parameters():
            param.requires_grad = False

    def forward(self, predicted, target):
        # Mean squared error loss
        mse = self.mse_loss(predicted, target)

        # Perceptual loss (VGG feature-based)
        predicted_vgg_features = self.vgg(predicted)
        target_vgg_features = self.vgg(target)
        perceptual_loss = self.mse_loss(predicted_vgg_features, target_vgg_features)

        # Combine losses
        loss = mse + perceptual_loss

        return loss

# %%
model = InpaintingModel()
model = model.to(device)
total_params = sum(p.numel() for p in model.parameters())
print(f"Number of parameters: {total_params}")
# Out:
# Number of parameters: 7303180

# %%
loss_fn = CombinedLoss().to(device)
adversarial_loss = nn.BCEWithLogitsLoss()
# Out:
# c:\Users\lenovo\Desktop\burak\ECE176\assignment6\.venv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
# %%time
loss_epoch_arr = []
num_epochs = 0
lr = [0.0002, 0.00005]
initial_memory_allocated = torch.cuda.memory_allocated() / (1024 ** 3)
print("Initial Memory Allocated: %0.2f Gigabytes" % initial_memory_allocated)

min_loss = 1000
for learn_rate in lr:
    opt = optim.Adam(model.parameters(), lr=learn_rate)
    max_epochs = 25
    for epoch in range(max_epochs):
        model.train()      
        num_epochs = num_epochs + 1                 
        for i, (X_input, X_mask, Y_output) in enumerate(Trainloader, 0):
            
            # Apply Gaussian noise to X_in
            X_in_noisy = add_gaussian_noise(X_input)
            X_input, X_mask, Y_output = X_in_noisy.to(device), X_mask.to(device), Y_output.to(device)

            opt.zero_grad()

            outputs = model(X_input, X_mask)
            l2_loss = loss_fn(Y_output, outputs)
            adv_loss = adversarial_loss(Y_output, outputs)
            loss = adv_loss + l2_loss
            loss.backward()

            opt.step()

            if min_loss > loss.item():
                min_loss = loss.item()
                best_model = copy.deepcopy(model.state_dict())
                print('Min loss %0.5f' % min_loss)
            
            if i % 10 == 0:
                print('Epoch: %d, Iteration: %d/%d, Loss: %0.5f, IoU: %0.5f' % (num_epochs, i, len(Trainloader), loss.item(), jaccard_coeff(Trainloader)))

            del X_input, X_mask, Y_output
            torch.cuda.empty_cache()
            
        loss_epoch_arr.append(loss.item())
# Out:
# Initial Memory Allocated: 0.06 Gigabytes
# Min loss 2.75310
# Epoch: 1, Iteration: 0/200, Loss: 2.75310, IoU: 0.32024
# Min loss 2.66149
# Min loss 2.59758
# Min loss 2.42152
# Min loss 2.40411
# Min loss 2.21384
# Min loss 2.18713
# Epoch: 1, Iteration: 10/200, Loss: 2.18713, IoU: 0.39644
# Min loss 2.11500
# Min loss 2.08955
# Min loss 2.01278
# Min loss 1.99754
# Min loss 1.88962
# Min loss 1.86599
# Min loss 1.76575
# Epoch: 1, Iteration: 20/200, Loss: 1.76575, IoU: 0.53008
# Min loss 1.73501
# Min loss 1.71065
# Min loss 1.69823
# Min loss 1.64679
# Min loss 1.62837
# Epoch: 1, Iteration: 30/200, Loss: 1.66020, IoU: 0.47644
# Min loss 1.60383
# Min loss 1.53748
# Min loss 1.53244
# Min loss 1.52942
# Epoch: 1, Iteration: 40/200, Loss: 1.52942, IoU: 0.50889
# Min loss 1.38184
# Epoch: 1, Iteration: 50/200, Loss: 1.46817, IoU: 0.46221
# Epoch: 1, Iteration: 60/200, Loss: 1.39935, IoU: 0.47456
# Min loss 1.36261
# Min loss 1.35495
# Epoch: 1, Iteration: 70/200, Loss: 1.35953, IoU: 0.47963
# Min loss 1.34210
# Epoch: 1, Iteration: 80/200, Loss: 1.36843, IoU: 0.47677
# Min loss 1.34004
# Min loss 1.32579
# Epoch: 1, Iteration: 90/200, Loss: 1.39455, IoU: 0.50483
# Min loss 1.31886
# Min loss 1.31369
# Min loss 1.24486
# Epoch: 1, Iteration: 100/200, Loss: 1.26917, IoU: 0.48497
# Epoch: 1, Iteration: 110/200, Loss: 1.30406, IoU: 0.45039
# Min loss 1.20163
# Epoch: 1, Iteration: 120/200, Loss: 1.31918, IoU: 0.46951
# Epoch: 1, Iteration: 130/200, Loss: 1.23486, IoU: 0.49236
# Epoch: 1, Iteration: 140/200, Loss: 1.28988, IoU: 0.47360
# Min loss 1.19285
# Epoch: 1, Iteration: 150/200, Loss: 1.19285, IoU: 0.48263
# Epoch: 1, Iteration: 160/200, Loss: 1.29115, IoU: 0.49662
# Min loss 1.19087
# Epoch: 1, Iteration: 170/200, Loss: 1.19087, IoU: 0.46337
# Min loss 1.15036
# Epoch: 1, Iteration: 180/200, Loss: 1.21861, IoU: 0.48572
# Epoch: 1, Iteration: 190/200, Loss: 1.22552, IoU: 0.47344
# Epoch: 2, Iteration: 0/200, Loss: 1.20878, IoU: 0.48581
# Epoch: 2, Iteration: 10/200, Loss: 1.18542, IoU: 0.45775
# Min loss 1.14827
# Epoch: 2, Iteration: 20/200, Loss: 1.21066, IoU: 0.47925
# Epoch: 2, Iteration: 30/200, Loss: 1.17084, IoU: 0.48220
# Min loss 1.14470
# Min loss 1.13811
# Epoch: 2, Iteration: 40/200, Loss: 1.13811, IoU: 0.45834
# Min loss 1.11964
# Min loss 1.09884
# Epoch: 2, Iteration: 50/200, Loss: 1.09884, IoU: 0.49765
# Epoch: 2, Iteration: 60/200, Loss: 1.18062, IoU: 0.45726
# Epoch: 2, Iteration: 70/200, Loss: 1.22822, IoU: 0.51425
# Epoch: 2, Iteration: 80/200, Loss: 1.13877, IoU: 0.48030
# Epoch: 2, Iteration: 90/200, Loss: 1.12286, IoU: 0.50266
# Epoch: 2, Iteration: 100/200, Loss: 1.13030, IoU: 0.47068
# Epoch: 2, Iteration: 110/200, Loss: 1.12854, IoU: 0.46180
# Epoch: 2, Iteration: 120/200, Loss: 1.20198, IoU: 0.48316
# Epoch: 2, Iteration: 130/200, Loss: 1.10532, IoU: 0.46479
# Epoch: 2, Iteration: 140/200, Loss: 1.14228, IoU: 0.48698
# Min loss 1.08473
# Epoch: 2, Iteration: 150/200, Loss: 1.09446, IoU: 0.49641
# Min loss 1.06107
# Epoch: 2, Iteration: 160/200, Loss: 1.10937, IoU: 0.45842
# Min loss 1.05940
# Epoch: 2, Iteration: 170/200, Loss: 1.05940, IoU: 0.51899
# Epoch: 2, Iteration: 180/200, Loss: 1.10846, IoU: 0.48937
# Epoch: 2, Iteration: 190/200, Loss: 1.09273, IoU: 0.46632
# Epoch: 3, Iteration: 0/200, Loss: 1.12881, IoU: 0.50660
# Epoch: 3, Iteration: 10/200, Loss: 1.10546, IoU: 0.50471
# Epoch: 3, Iteration: 20/200, Loss: 1.09824, IoU: 0.50916
# Epoch: 3, Iteration: 30/200, Loss: 1.08152, IoU: 0.46986
# Min loss 1.05708
# Min loss 1.05327
# Epoch: 3, Iteration: 40/200, Loss: 1.09666, IoU: 0.45294
# Min loss 1.03872
# Epoch: 3, Iteration: 50/200, Loss: 1.10168, IoU: 0.49808
# Epoch: 3, Iteration: 60/200, Loss: 1.14498, IoU: 0.49573
# Min loss 1.03823
# Epoch: 3, Iteration: 70/200, Loss: 1.09848, IoU: 0.46787
# Epoch: 3, Iteration: 80/200, Loss: 1.09136, IoU: 0.46049
# Epoch: 3, Iteration: 90/200, Loss: 1.09033, IoU: 0.43236
# Epoch: 3, Iteration: 100/200, Loss: 1.05003, IoU: 0.49615
# Min loss 1.01928
# Min loss 1.01670
# Epoch: 3, Iteration: 110/200, Loss: 1.01816, IoU: 0.48867
# Epoch: 3, Iteration: 120/200, Loss: 1.04842, IoU: 0.45953
# Epoch: 3, Iteration: 130/200, Loss: 1.09045, IoU: 0.49718
# Epoch: 3, Iteration: 140/200, Loss: 1.07502, IoU: 0.47554
# Epoch: 3, Iteration: 150/200, Loss: 1.08877, IoU: 0.49587
# Min loss 0.99463
# Epoch: 3, Iteration: 160/200, Loss: 1.09801, IoU: 0.50680
# Epoch: 3, Iteration: 170/200, Loss: 1.06479, IoU: 0.46788
# Epoch: 3, Iteration: 180/200, Loss: 1.03601, IoU: 0.47076
# Epoch: 3, Iteration: 190/200, Loss: 1.06972, IoU: 0.46198
# Epoch: 4, Iteration: 0/200, Loss: 1.06137, IoU: 0.47983
# Epoch: 4, Iteration: 10/200, Loss: 1.04397, IoU: 0.49304
# Epoch: 4, Iteration: 20/200, Loss: 1.06050, IoU: 0.47526
# Epoch: 4, Iteration: 30/200, Loss: 1.07394, IoU: 0.50081
# Epoch: 4, Iteration: 40/200, Loss: 1.02037, IoU: 0.47179
# Epoch: 4, Iteration: 50/200, Loss: 1.04718, IoU: 0.48545
# Epoch: 4, Iteration: 60/200, Loss: 1.06098, IoU: 0.47389
# Epoch: 4, Iteration: 70/200, Loss: 1.04482, IoU: 0.48327
# Epoch: 4, Iteration: 80/200, Loss: 1.05828, IoU: 0.46054
# Epoch: 4, Iteration: 90/200, Loss: 1.05924, IoU: 0.51680
# Epoch: 4, Iteration: 100/200, Loss: 1.03521, IoU: 0.44978
# Epoch: 4, Iteration: 110/200, Loss: 1.05075, IoU: 0.45679
# Epoch: 4, Iteration: 120/200, Loss: 1.08722, IoU: 0.47302
# Epoch: 4, Iteration: 130/200, Loss: 1.05584, IoU: 0.47858
# Epoch: 4, Iteration: 140/200, Loss: 1.04134, IoU: 0.49898
# Epoch: 4, Iteration: 150/200, Loss: 1.04364, IoU: 0.48282
# Epoch: 4, Iteration: 160/200, Loss: 1.04582, IoU: 0.50878
# Epoch: 4, Iteration: 170/200, Loss: 1.04885, IoU: 0.46289
# Epoch: 4, Iteration: 180/200, Loss: 1.04487, IoU: 0.49123
# Epoch: 4, Iteration: 190/200, Loss: 1.04976, IoU: 0.45893
# Epoch: 5, Iteration: 0/200, Loss: 1.05327, IoU: 0.49440
# Epoch: 5, Iteration: 10/200, Loss: 1.07103, IoU: 0.49954
# Epoch: 5, Iteration: 20/200, Loss: 1.05587, IoU: 0.48615
# Epoch: 5, Iteration: 30/200, Loss: 1.00595, IoU: 0.43875
# Epoch: 5, Iteration: 40/200, Loss: 1.05292, IoU: 0.47263
# Epoch: 5, Iteration: 50/200, Loss: 1.04761, IoU: 0.49789
# Epoch: 5, Iteration: 60/200, Loss: 1.03577, IoU: 0.48486
# Epoch: 5, Iteration: 70/200, Loss: 1.04499, IoU: 0.49516
# Epoch: 5, Iteration: 80/200, Loss: 1.01630, IoU: 0.48081
# Epoch: 5, Iteration: 90/200, Loss: 1.04181, IoU: 0.47938
# Epoch: 5, Iteration: 100/200, Loss: 1.01957, IoU: 0.51738
# Epoch: 5, Iteration: 110/200, Loss: 1.02640, IoU: 0.49987
# Min loss 0.98341
# Epoch: 5, Iteration: 120/200, Loss: 1.02556, IoU: 0.49257
# Epoch: 5, Iteration: 130/200, Loss: 1.01836, IoU: 0.48629
# Epoch: 5, Iteration: 140/200, Loss: 1.04909, IoU: 0.49006
# Epoch: 5, Iteration: 150/200, Loss: 1.04229, IoU: 0.48753
# Epoch: 5, Iteration: 160/200, Loss: 1.04795, IoU: 0.49403
# Min loss 0.96142
# Epoch: 5, Iteration: 170/200, Loss: 1.04356, IoU: 0.49926
# Epoch: 5, Iteration: 180/200, Loss: 1.04480, IoU: 0.48658
# Epoch: 5, Iteration: 190/200, Loss: 1.05694, IoU: 0.46873
# Epoch: 6, Iteration: 0/200, Loss: 1.04657, IoU: 0.43651
# Epoch: 6, Iteration: 10/200, Loss: 1.02723, IoU: 0.46776
# Epoch: 6, Iteration: 20/200, Loss: 1.03798, IoU: 0.46556
# Epoch: 6, Iteration: 30/200, Loss: 1.05282, IoU: 0.48359
# Epoch: 6, Iteration: 40/200, Loss: 1.01339, IoU: 0.46379
# Epoch: 6, Iteration: 50/200, Loss: 0.99767, IoU: 0.44726
# Epoch: 6, Iteration: 60/200, Loss: 1.01639, IoU: 0.50322
# Epoch: 6, Iteration: 70/200, Loss: 1.01184, IoU: 0.51425
# Epoch: 6, Iteration: 80/200, Loss: 1.02966, IoU: 0.51083
# Epoch: 6, Iteration: 90/200, Loss: 1.04030, IoU: 0.42613
# Epoch: 6, Iteration: 100/200, Loss: 1.06007, IoU: 0.49455
# Epoch: 6, Iteration: 110/200, Loss: 1.02310, IoU: 0.51789
# Epoch: 6, Iteration: 120/200, Loss: 1.04384, IoU: 0.47345
# Epoch: 6, Iteration: 130/200, Loss: 1.06617, IoU: 0.48921
# Epoch: 6, Iteration: 140/200, Loss: 1.00672, IoU: 0.49663
# Epoch: 6, Iteration: 150/200, Loss: 1.01175, IoU: 0.49964
# Epoch: 6, Iteration: 160/200, Loss: 0.97271, IoU: 0.48150
# Epoch: 6, Iteration: 170/200, Loss: 0.99751, IoU: 0.49960
# Epoch: 6, Iteration: 180/200, Loss: 1.00330, IoU: 0.50622
# Epoch: 6, Iteration: 190/200, Loss: 1.00548, IoU: 0.49464
# Epoch: 7, Iteration: 0/200, Loss: 1.00637, IoU: 0.49438
# Epoch: 7, Iteration: 10/200, Loss: 1.00216, IoU: 0.46555
# Epoch: 7, Iteration: 20/200, Loss: 0.98792, IoU: 0.49490
# Epoch: 7, Iteration: 30/200, Loss: 1.02857, IoU: 0.46697
# Epoch: 7, Iteration: 40/200, Loss: 1.05693, IoU: 0.48208
# Epoch: 7, Iteration: 50/200, Loss: 1.02156, IoU: 0.49899
# Epoch: 7, Iteration: 60/200, Loss: 1.01412, IoU: 0.49767
# Epoch: 7, Iteration: 70/200, Loss: 0.99670, IoU: 0.45010
# Min loss 0.95540
# Epoch: 7, Iteration: 80/200, Loss: 1.04309, IoU: 0.49304
# Epoch: 7, Iteration: 90/200, Loss: 1.00855, IoU: 0.45163
# Epoch: 7, Iteration: 100/200, Loss: 1.01304, IoU: 0.50220
# Epoch: 7, Iteration: 110/200, Loss: 0.98925, IoU: 0.44523
# Epoch: 7, Iteration: 120/200, Loss: 1.00478, IoU: 0.50440
# Epoch: 7, Iteration: 130/200, Loss: 1.01828, IoU: 0.50874
# Epoch: 7, Iteration: 140/200, Loss: 1.03049, IoU: 0.50609
# Epoch: 7, Iteration: 150/200, Loss: 1.02091, IoU: 0.50494
# Min loss 0.95398
# Epoch: 7, Iteration: 160/200, Loss: 0.99466, IoU: 0.47984
# Epoch: 7, Iteration: 170/200, Loss: 0.97759, IoU: 0.48057
# Epoch: 7, Iteration: 180/200, Loss: 0.99119, IoU: 0.50058
# Epoch: 7, Iteration: 190/200, Loss: 1.01042, IoU: 0.47934
# Epoch: 8, Iteration: 0/200, Loss: 1.00796, IoU: 0.45077
# Epoch: 8, Iteration: 10/200, Loss: 1.00561, IoU: 0.46713
# Epoch: 8, Iteration: 20/200, Loss: 1.00536, IoU: 0.47877
# Epoch: 8, Iteration: 30/200, Loss: 0.97768, IoU: 0.50016
# Epoch: 8, Iteration: 40/200, Loss: 0.97422, IoU: 0.46889
# Epoch: 8, Iteration: 50/200, Loss: 0.98950, IoU: 0.49081
# Epoch: 8, Iteration: 60/200, Loss: 1.03290, IoU: 0.47684
# Epoch: 8, Iteration: 70/200, Loss: 0.99485, IoU: 0.48565
# Min loss 0.94474
# Epoch: 8, Iteration: 80/200, Loss: 1.01245, IoU: 0.46460
# Epoch: 8, Iteration: 90/200, Loss: 0.97460, IoU: 0.47207
# Epoch: 8, Iteration: 100/200, Loss: 1.01170, IoU: 0.48455
# Epoch: 8, Iteration: 110/200, Loss: 1.02981, IoU: 0.49653
# Epoch: 8, Iteration: 120/200, Loss: 1.03128, IoU: 0.49062
# Epoch: 8, Iteration: 130/200, Loss: 0.97729, IoU: 0.47515
# Epoch: 8, Iteration: 140/200, Loss: 1.00804, IoU: 0.48903
# Epoch: 8, Iteration: 150/200, Loss: 0.98001, IoU: 0.48715
# Epoch: 8, Iteration: 160/200, Loss: 0.97689, IoU: 0.51694
# Epoch: 8, Iteration: 170/200, Loss: 0.99589, IoU: 0.48337
# Epoch: 8, Iteration: 180/200, Loss: 0.97912, IoU: 0.47480
# Epoch: 8, Iteration: 190/200, Loss: 0.99142, IoU: 0.49967
# Epoch: 9, Iteration: 0/200, Loss: 1.00269, IoU: 0.47026
# Epoch: 9, Iteration: 10/200, Loss: 1.00741, IoU: 0.48808
# Epoch: 9, Iteration: 20/200, Loss: 1.00079, IoU: 0.48425
# Epoch: 9, Iteration: 30/200, Loss: 1.01062, IoU: 0.48918
# Epoch: 9, Iteration: 40/200, Loss: 0.98021, IoU: 0.49325
# Epoch: 9, Iteration: 50/200, Loss: 0.99120, IoU: 0.48881
# Epoch: 9, Iteration: 60/200, Loss: 1.00059, IoU: 0.48952
# Epoch: 9, Iteration: 70/200, Loss: 1.06034, IoU: 0.49896
# Epoch: 9, Iteration: 80/200, Loss: 1.00453, IoU: 0.48213
# Epoch: 9, Iteration: 90/200, Loss: 0.98055, IoU: 0.49486
# Epoch: 9, Iteration: 100/200, Loss: 0.95850, IoU: 0.47296
# Min loss 0.93939
# Epoch: 9, Iteration: 110/200, Loss: 0.97418, IoU: 0.53064
# Epoch: 9, Iteration: 120/200, Loss: 0.98291, IoU: 0.48302
# Epoch: 9, Iteration: 130/200, Loss: 0.98022, IoU: 0.50425
# Epoch: 9, Iteration: 140/200, Loss: 0.98336, IoU: 0.51667
# Epoch: 9, Iteration: 150/200, Loss: 0.98464, IoU: 0.47811
# Epoch: 9, Iteration: 160/200, Loss: 0.96785, IoU: 0.49965
# Epoch: 9, Iteration: 170/200, Loss: 1.03035, IoU: 0.47417
# Epoch: 9, Iteration: 180/200, Loss: 0.94914, IoU: 0.48679
# Epoch: 9, Iteration: 190/200, Loss: 0.99811, IoU: 0.49421
# Epoch: 10, Iteration: 0/200, Loss: 0.97717, IoU: 0.45952
# Epoch: 10, Iteration: 10/200, Loss: 0.98133, IoU: 0.46035
# Epoch: 10, Iteration: 20/200, Loss: 1.02654, IoU: 0.46505
# Epoch: 10, Iteration: 30/200, Loss: 0.99699, IoU: 0.45884
# Epoch: 10, Iteration: 40/200, Loss: 1.01147, IoU: 0.49649
# Epoch: 10, Iteration: 50/200, Loss: 0.99418, IoU: 0.48717
# Epoch: 10, Iteration: 60/200, Loss: 0.98191, IoU: 0.50946
# Epoch: 10, Iteration: 70/200, Loss: 0.95443, IoU: 0.50774
# Epoch: 10, Iteration: 80/200, Loss: 0.94998, IoU: 0.50444
# Epoch: 10, Iteration: 90/200, Loss: 0.97453, IoU: 0.53737
# Epoch: 10, Iteration: 100/200, Loss: 0.97679, IoU: 0.47563
# Epoch: 10, Iteration: 110/200, Loss: 0.98388, IoU: 0.49595
# Epoch: 10, Iteration: 120/200, Loss: 0.95212, IoU: 0.48722
# Epoch: 10, Iteration: 130/200, Loss: 0.97553, IoU: 0.49110
# Epoch: 10, Iteration: 140/200, Loss: 0.97419, IoU: 0.48813
# Epoch: 10, Iteration: 150/200, Loss: 0.99394, IoU: 0.51002
# Epoch: 10, Iteration: 160/200, Loss: 0.98177, IoU: 0.49931
# Epoch: 10, Iteration: 170/200, Loss: 1.00532, IoU: 0.49632
# Epoch: 10, Iteration: 180/200, Loss: 0.96846, IoU: 0.50671
# Epoch: 10, Iteration: 190/200, Loss: 1.00607, IoU: 0.46734
# Min loss 0.93143
# Epoch: 11, Iteration: 0/200, Loss: 0.97113, IoU: 0.52769
# Epoch: 11, Iteration: 10/200, Loss: 0.97559, IoU: 0.45354
# Epoch: 11, Iteration: 20/200, Loss: 0.98596, IoU: 0.48536
# Epoch: 11, Iteration: 30/200, Loss: 0.97969, IoU: 0.53400
# Epoch: 11, Iteration: 40/200, Loss: 0.98729, IoU: 0.47680
# Epoch: 11, Iteration: 50/200, Loss: 0.99098, IoU: 0.45868
# Epoch: 11, Iteration: 60/200, Loss: 0.99167, IoU: 0.50667
# Epoch: 11, Iteration: 70/200, Loss: 0.99212, IoU: 0.50070
# Epoch: 11, Iteration: 80/200, Loss: 0.97744, IoU: 0.47135
# Epoch: 11, Iteration: 90/200, Loss: 0.98259, IoU: 0.45831
# Epoch: 11, Iteration: 100/200, Loss: 0.98308, IoU: 0.50709
# Epoch: 11, Iteration: 110/200, Loss: 0.94228, IoU: 0.48919
# Epoch: 11, Iteration: 120/200, Loss: 0.99225, IoU: 0.48433
# Min loss 0.93022
# Epoch: 11, Iteration: 130/200, Loss: 0.97206, IoU: 0.47908
# Epoch: 11, Iteration: 140/200, Loss: 0.99922, IoU: 0.46878
# Epoch: 11, Iteration: 150/200, Loss: 0.96365, IoU: 0.49848
# Epoch: 11, Iteration: 160/200, Loss: 0.98267, IoU: 0.48478
# Epoch: 11, Iteration: 170/200, Loss: 1.01538, IoU: 0.47613
# Epoch: 11, Iteration: 180/200, Loss: 0.99210, IoU: 0.45035
# Epoch: 11, Iteration: 190/200, Loss: 0.97786, IoU: 0.47836
# Epoch: 12, Iteration: 0/200, Loss: 0.99950, IoU: 0.46042
# Epoch: 12, Iteration: 10/200, Loss: 0.96445, IoU: 0.45601
# Epoch: 12, Iteration: 20/200, Loss: 0.98206, IoU: 0.48399
# Epoch: 12, Iteration: 30/200, Loss: 0.96798, IoU: 0.49497
# Epoch: 12, Iteration: 40/200, Loss: 0.96185, IoU: 0.50613
# Epoch: 12, Iteration: 50/200, Loss: 0.95689, IoU: 0.48333
# Min loss 0.92150
# Epoch: 12, Iteration: 60/200, Loss: 0.99062, IoU: 0.48323
# Epoch: 12, Iteration: 70/200, Loss: 0.97466, IoU: 0.46588
# Epoch: 12, Iteration: 80/200, Loss: 1.00349, IoU: 0.48012
# Epoch: 12, Iteration: 90/200, Loss: 0.99381, IoU: 0.51843
# Epoch: 12, Iteration: 100/200, Loss: 0.95163, IoU: 0.46915
# Epoch: 12, Iteration: 110/200, Loss: 0.99446, IoU: 0.46657
# Epoch: 12, Iteration: 120/200, Loss: 0.96018, IoU: 0.49924
# Epoch: 12, Iteration: 130/200, Loss: 0.98388, IoU: 0.48193
# Epoch: 12, Iteration: 140/200, Loss: 0.98426, IoU: 0.50025
# Epoch: 12, Iteration: 150/200, Loss: 0.99842, IoU: 0.47891
# Epoch: 12, Iteration: 160/200, Loss: 0.93749, IoU: 0.48546
# Epoch: 12, Iteration: 170/200, Loss: 0.95686, IoU: 0.48538
# Epoch: 12, Iteration: 180/200, Loss: 0.99273, IoU: 0.48253
# Epoch: 12, Iteration: 190/200, Loss: 0.97229, IoU: 0.48344
# Epoch: 13, Iteration: 0/200, Loss: 0.95960, IoU: 0.48695
# Epoch: 13, Iteration: 10/200, Loss: 0.97509, IoU: 0.47902
# Min loss 0.91464
# Epoch: 13, Iteration: 20/200, Loss: 0.91464, IoU: 0.48788
# Epoch: 13, Iteration: 30/200, Loss: 0.93785, IoU: 0.49515
# Epoch: 13, Iteration: 40/200, Loss: 0.93658, IoU: 0.49705
# Epoch: 13, Iteration: 50/200, Loss: 0.97475, IoU: 0.48986
# Epoch: 13, Iteration: 60/200, Loss: 0.98253, IoU: 0.45789
# Epoch: 13, Iteration: 70/200, Loss: 0.96977, IoU: 0.51225
# Epoch: 13, Iteration: 80/200, Loss: 1.01547, IoU: 0.50153
# Epoch: 13, Iteration: 90/200, Loss: 0.97665, IoU: 0.48982
# Epoch: 13, Iteration: 100/200, Loss: 0.96393, IoU: 0.46717
# Epoch: 13, Iteration: 110/200, Loss: 0.96785, IoU: 0.47035
# Epoch: 13, Iteration: 120/200, Loss: 0.94574, IoU: 0.48113
# Epoch: 13, Iteration: 130/200, Loss: 0.97741, IoU: 0.45051
# Epoch: 13, Iteration: 140/200, Loss: 0.96917, IoU: 0.56143
# Epoch: 13, Iteration: 150/200, Loss: 0.95222, IoU: 0.50170
# Epoch: 13, Iteration: 160/200, Loss: 0.98212, IoU: 0.48580
# Epoch: 13, Iteration: 170/200, Loss: 0.99369, IoU: 0.50472
# Epoch: 13, Iteration: 180/200, Loss: 0.95745, IoU: 0.47293
# Epoch: 13, Iteration: 190/200, Loss: 0.97691, IoU: 0.47949
# Min loss 0.90898
# Epoch: 14, Iteration: 0/200, Loss: 0.97189, IoU: 0.50315
# Epoch: 14, Iteration: 10/200, Loss: 0.96087, IoU: 0.50183
# Epoch: 14, Iteration: 20/200, Loss: 0.95880, IoU: 0.48744
# Epoch: 14, Iteration: 30/200, Loss: 0.94108, IoU: 0.53366
# Epoch: 14, Iteration: 40/200, Loss: 0.94761, IoU: 0.48572
# Epoch: 14, Iteration: 50/200, Loss: 0.98066, IoU: 0.49147
# Epoch: 14, Iteration: 60/200, Loss: 0.98407, IoU: 0.50840
# Epoch: 14, Iteration: 70/200, Loss: 0.96890, IoU: 0.47224
# Epoch: 14, Iteration: 80/200, Loss: 0.94230, IoU: 0.48262
# Epoch: 14, Iteration: 90/200, Loss: 1.00521, IoU: 0.50379
# Epoch: 14, Iteration: 100/200, Loss: 0.97693, IoU: 0.47859
# Epoch: 14, Iteration: 110/200, Loss: 0.97744, IoU: 0.50140
# Epoch: 14, Iteration: 120/200, Loss: 0.97512, IoU: 0.48286
# Epoch: 14, Iteration: 130/200, Loss: 0.98568, IoU: 0.48398
# Epoch: 14, Iteration: 140/200, Loss: 0.92322, IoU: 0.50023
# Epoch: 14, Iteration: 150/200, Loss: 0.93170, IoU: 0.51930
# Epoch: 14, Iteration: 160/200, Loss: 0.94057, IoU: 0.46159
# Epoch: 14, Iteration: 170/200, Loss: 0.96933, IoU: 0.48731
# Epoch: 14, Iteration: 180/200, Loss: 0.99193, IoU: 0.47347
# Epoch: 14, Iteration: 190/200, Loss: 0.93859, IoU: 0.47071
# Epoch: 15, Iteration: 0/200, Loss: 0.96688, IoU: 0.50762
# Epoch: 15, Iteration: 10/200, Loss: 0.98900, IoU: 0.48632
# Epoch: 15, Iteration: 20/200, Loss: 0.95345, IoU: 0.45905
# Epoch: 15, Iteration: 30/200, Loss: 0.97355, IoU: 0.53233
# Epoch: 15, Iteration: 40/200, Loss: 0.98573, IoU: 0.48630
# Epoch: 15, Iteration: 50/200, Loss: 0.98086, IoU: 0.48649
# Epoch: 15, Iteration: 60/200, Loss: 0.94851, IoU: 0.53131
# Epoch: 15, Iteration: 70/200, Loss: 1.00079, IoU: 0.47376
# Epoch: 15, Iteration: 80/200, Loss: 0.98105, IoU: 0.49364
# Epoch: 15, Iteration: 90/200, Loss: 0.96869, IoU: 0.50729
# Epoch: 15, Iteration: 100/200, Loss: 0.96204, IoU: 0.46257
# Epoch: 15, Iteration: 110/200, Loss: 0.95038, IoU: 0.48416
# Epoch: 15, Iteration: 120/200, Loss: 0.96905, IoU: 0.48195
# Epoch: 15, Iteration: 130/200, Loss: 0.99815, IoU: 0.49853
# Epoch: 15, Iteration: 140/200, Loss: 0.95197, IoU: 0.49998
# Epoch: 15, Iteration: 150/200, Loss: 0.95932, IoU: 0.48764
# Min loss 0.90057
# Epoch: 15, Iteration: 160/200, Loss: 0.96949, IoU: 0.48970
# Epoch: 15, Iteration: 170/200, Loss: 0.95862, IoU: 0.48793
# Epoch: 15, Iteration: 180/200, Loss: 0.94506, IoU: 0.45684
# Epoch: 15, Iteration: 190/200, Loss: 0.95402, IoU: 0.48630
# Epoch: 16, Iteration: 0/200, Loss: 0.94670, IoU: 0.50476
# Epoch: 16, Iteration: 10/200, Loss: 0.95723, IoU: 0.49400
# Epoch: 16, Iteration: 20/200, Loss: 0.98856, IoU: 0.52207
# Epoch: 16, Iteration: 30/200, Loss: 0.94985, IoU: 0.49721
# Epoch: 16, Iteration: 40/200, Loss: 0.96935, IoU: 0.46916
# Epoch: 16, Iteration: 50/200, Loss: 0.94709, IoU: 0.49539
# Epoch: 16, Iteration: 60/200, Loss: 0.94040, IoU: 0.51292
# Epoch: 16, Iteration: 70/200, Loss: 0.98339, IoU: 0.48304
# Epoch: 16, Iteration: 80/200, Loss: 0.96009, IoU: 0.45897
# Epoch: 16, Iteration: 90/200, Loss: 0.99427, IoU: 0.54716
# Epoch: 16, Iteration: 100/200, Loss: 0.95334, IoU: 0.47527
# Epoch: 16, Iteration: 110/200, Loss: 0.95095, IoU: 0.50078
# Epoch: 16, Iteration: 120/200, Loss: 0.96592, IoU: 0.51408
# Epoch: 16, Iteration: 130/200, Loss: 0.95028, IoU: 0.49219
# Epoch: 16, Iteration: 140/200, Loss: 0.98975, IoU: 0.50803
# Epoch: 16, Iteration: 150/200, Loss: 0.93394, IoU: 0.51055
# Epoch: 16, Iteration: 160/200, Loss: 0.98008, IoU: 0.49925
# Epoch: 16, Iteration: 170/200, Loss: 0.96332, IoU: 0.51390
# Epoch: 16, Iteration: 180/200, Loss: 0.98000, IoU: 0.46830
# Epoch: 16, Iteration: 190/200, Loss: 0.99910, IoU: 0.46945
# Epoch: 17, Iteration: 0/200, Loss: 0.97011, IoU: 0.48117
# Epoch: 17, Iteration: 10/200, Loss: 0.93757, IoU: 0.48027
# Epoch: 17, Iteration: 20/200, Loss: 0.99878, IoU: 0.49312
# Epoch: 17, Iteration: 30/200, Loss: 0.93816, IoU: 0.49341
# Epoch: 17, Iteration: 40/200, Loss: 0.95656, IoU: 0.51022
# Epoch: 17, Iteration: 50/200, Loss: 0.94018, IoU: 0.50807
# Epoch: 17, Iteration: 60/200, Loss: 0.98435, IoU: 0.51039
# Epoch: 17, Iteration: 70/200, Loss: 0.94753, IoU: 0.47036
# Epoch: 17, Iteration: 80/200, Loss: 0.95640, IoU: 0.46215
# Epoch: 17, Iteration: 90/200, Loss: 0.99731, IoU: 0.48206
# Epoch: 17, Iteration: 100/200, Loss: 0.95903, IoU: 0.49264
# Epoch: 17, Iteration: 110/200, Loss: 0.95676, IoU: 0.49727
# Epoch: 17, Iteration: 120/200, Loss: 0.93206, IoU: 0.50404
# Epoch: 17, Iteration: 130/200, Loss: 0.99053, IoU: 0.50845
# Epoch: 17, Iteration: 140/200, Loss: 0.95304, IoU: 0.45384
# Epoch: 17, Iteration: 150/200, Loss: 0.93587, IoU: 0.51270
# Epoch: 17, Iteration: 160/200, Loss: 0.94387, IoU: 0.51405
# Epoch: 17, Iteration: 170/200, Loss: 0.95370, IoU: 0.46572
# Epoch: 17, Iteration: 180/200, Loss: 0.96066, IoU: 0.49244
# Epoch: 17, Iteration: 190/200, Loss: 0.96602, IoU: 0.49050
# Epoch: 18, Iteration: 0/200, Loss: 0.93881, IoU: 0.47992
# Epoch: 18, Iteration: 10/200, Loss: 0.93454, IoU: 0.47555
# Epoch: 18, Iteration: 20/200, Loss: 0.95460, IoU: 0.49780
# Epoch: 18, Iteration: 30/200, Loss: 0.96931, IoU: 0.46642
# Epoch: 18, Iteration: 40/200, Loss: 0.92680, IoU: 0.52225
# Epoch: 18, Iteration: 50/200, Loss: 0.97190, IoU: 0.47406
# Epoch: 18, Iteration: 60/200, Loss: 0.96768, IoU: 0.48905
# Epoch: 18, Iteration: 70/200, Loss: 0.92781, IoU: 0.50076
# Epoch: 18, Iteration: 80/200, Loss: 0.91825, IoU: 0.52061
# Epoch: 18, Iteration: 90/200, Loss: 0.96969, IoU: 0.45969
# Epoch: 18, Iteration: 100/200, Loss: 0.96881, IoU: 0.48484
# Epoch: 18, Iteration: 110/200, Loss: 0.94141, IoU: 0.46426
# Epoch: 18, Iteration: 120/200, Loss: 0.96889, IoU: 0.50167
# Epoch: 18, Iteration: 130/200, Loss: 0.96610, IoU: 0.46338
# Epoch: 18, Iteration: 140/200, Loss: 0.96551, IoU: 0.52353
# Epoch: 18, Iteration: 150/200, Loss: 0.97155, IoU: 0.51194
# Epoch: 18, Iteration: 160/200, Loss: 0.96344, IoU: 0.48314
# Epoch: 18, Iteration: 170/200, Loss: 0.91528, IoU: 0.50195
# Epoch: 18, Iteration: 180/200, Loss: 0.91079, IoU: 0.51013
# Epoch: 18, Iteration: 190/200, Loss: 0.93111, IoU: 0.45179
# Epoch: 19, Iteration: 0/200, Loss: 0.95400, IoU: 0.50301
# Epoch: 19, Iteration: 10/200, Loss: 0.93051, IoU: 0.47537
# Epoch: 19, Iteration: 20/200, Loss: 0.93481, IoU: 0.48163
# Epoch: 19, Iteration: 30/200, Loss: 0.93471, IoU: 0.49907
# Epoch: 19, Iteration: 40/200, Loss: 0.95028, IoU: 0.51751
# Epoch: 19, Iteration: 50/200, Loss: 0.98133, IoU: 0.49457
# Epoch: 19, Iteration: 60/200, Loss: 0.94977, IoU: 0.49583
# Epoch: 19, Iteration: 70/200, Loss: 0.96630, IoU: 0.49256
# Epoch: 19, Iteration: 80/200, Loss: 0.97606, IoU: 0.49998
# Epoch: 19, Iteration: 90/200, Loss: 0.99759, IoU: 0.49143
# Epoch: 19, Iteration: 100/200, Loss: 0.93548, IoU: 0.50761
# Epoch: 19, Iteration: 110/200, Loss: 0.98749, IoU: 0.47869
# Epoch: 19, Iteration: 120/200, Loss: 0.94430, IoU: 0.47100
# Epoch: 19, Iteration: 130/200, Loss: 0.91834, IoU: 0.49327
# Epoch: 19, Iteration: 140/200, Loss: 0.96277, IoU: 0.49617
# Epoch: 19, Iteration: 150/200, Loss: 0.93536, IoU: 0.50352
# Epoch: 19, Iteration: 160/200, Loss: 0.93665, IoU: 0.49860
# Epoch: 19, Iteration: 170/200, Loss: 0.93880, IoU: 0.47844
# Epoch: 19, Iteration: 180/200, Loss: 0.95607, IoU: 0.46281
# Min loss 0.89864
# Epoch: 19, Iteration: 190/200, Loss: 0.89864, IoU: 0.48558
# Epoch: 20, Iteration: 0/200, Loss: 0.99733, IoU: 0.51341
# Epoch: 20, Iteration: 10/200, Loss: 0.97884, IoU: 0.50868
# Epoch: 20, Iteration: 20/200, Loss: 0.95595, IoU: 0.50048
# Epoch: 20, Iteration: 30/200, Loss: 0.93618, IoU: 0.47832
# Epoch: 20, Iteration: 40/200, Loss: 0.93244, IoU: 0.50105
# Epoch: 20, Iteration: 50/200, Loss: 0.94375, IoU: 0.51224
# Epoch: 20, Iteration: 60/200, Loss: 0.92632, IoU: 0.48360
# Epoch: 20, Iteration: 70/200, Loss: 0.95487, IoU: 0.48123
# Epoch: 20, Iteration: 80/200, Loss: 0.94915, IoU: 0.45915
# Epoch: 20, Iteration: 90/200, Loss: 0.93075, IoU: 0.49437
# Min loss 0.89031
# Epoch: 20, Iteration: 100/200, Loss: 0.98131, IoU: 0.46080
# Epoch: 20, Iteration: 110/200, Loss: 0.94562, IoU: 0.50628
# Epoch: 20, Iteration: 120/200, Loss: 0.93796, IoU: 0.51911
# Epoch: 20, Iteration: 130/200, Loss: 0.93938, IoU: 0.49669
# Epoch: 20, Iteration: 140/200, Loss: 0.92836, IoU: 0.48488
# Epoch: 20, Iteration: 150/200, Loss: 0.91402, IoU: 0.50704
# Epoch: 20, Iteration: 160/200, Loss: 0.92982, IoU: 0.49621
# Epoch: 20, Iteration: 170/200, Loss: 0.94486, IoU: 0.48952
# Epoch: 20, Iteration: 180/200, Loss: 0.93987, IoU: 0.47193
# Epoch: 20, Iteration: 190/200, Loss: 0.93582, IoU: 0.48853
# Epoch: 21, Iteration: 0/200, Loss: 0.91194, IoU: 0.47981
# Epoch: 21, Iteration: 10/200, Loss: 0.96747, IoU: 0.46037
# Epoch: 21, Iteration: 20/200, Loss: 0.92041, IoU: 0.47871
# Epoch: 21, Iteration: 30/200, Loss: 0.92022, IoU: 0.49999
# Epoch: 21, Iteration: 40/200, Loss: 0.93453, IoU: 0.47669
# Epoch: 21, Iteration: 50/200, Loss: 0.96945, IoU: 0.50764
# Epoch: 21, Iteration: 60/200, Loss: 0.95428, IoU: 0.50127
# Epoch: 21, Iteration: 70/200, Loss: 0.92490, IoU: 0.48858
# Epoch: 21, Iteration: 80/200, Loss: 0.92288, IoU: 0.51701
# Epoch: 21, Iteration: 90/200, Loss: 0.92500, IoU: 0.48738
# Epoch: 21, Iteration: 100/200, Loss: 0.95563, IoU: 0.48291
# Min loss 0.88842
# Epoch: 21, Iteration: 110/200, Loss: 0.95914, IoU: 0.50245
# Epoch: 21, Iteration: 120/200, Loss: 0.94212, IoU: 0.51772
# Epoch: 21, Iteration: 130/200, Loss: 0.95017, IoU: 0.48625
# Epoch: 21, Iteration: 140/200, Loss: 0.91760, IoU: 0.51441
# Epoch: 21, Iteration: 150/200, Loss: 0.92678, IoU: 0.49121
# Epoch: 21, Iteration: 160/200, Loss: 0.91490, IoU: 0.47026
# Epoch: 21, Iteration: 170/200, Loss: 0.91724, IoU: 0.52548
# Epoch: 21, Iteration: 180/200, Loss: 0.95527, IoU: 0.45283
# Epoch: 21, Iteration: 190/200, Loss: 0.94420, IoU: 0.47046
# Epoch: 22, Iteration: 0/200, Loss: 0.96031, IoU: 0.49567
# Epoch: 22, Iteration: 10/200, Loss: 0.92206, IoU: 0.48530
# Epoch: 22, Iteration: 20/200, Loss: 0.92904, IoU: 0.46979
# Epoch: 22, Iteration: 30/200, Loss: 0.95590, IoU: 0.51724
# Epoch: 22, Iteration: 40/200, Loss: 0.96284, IoU: 0.49073
# Epoch: 22, Iteration: 50/200, Loss: 0.95043, IoU: 0.48577
# Epoch: 22, Iteration: 60/200, Loss: 0.92099, IoU: 0.49307
# Epoch: 22, Iteration: 70/200, Loss: 0.95577, IoU: 0.47992
# Epoch: 22, Iteration: 80/200, Loss: 0.95063, IoU: 0.50853
# Epoch: 22, Iteration: 90/200, Loss: 0.95470, IoU: 0.48206
# Epoch: 22, Iteration: 100/200, Loss: 0.94403, IoU: 0.51554
# Epoch: 22, Iteration: 110/200, Loss: 0.94682, IoU: 0.47914
# Epoch: 22, Iteration: 120/200, Loss: 0.93719, IoU: 0.46431
# Epoch: 22, Iteration: 130/200, Loss: 0.93468, IoU: 0.47029
# Epoch: 22, Iteration: 140/200, Loss: 0.92520, IoU: 0.44811
# Epoch: 22, Iteration: 150/200, Loss: 0.93840, IoU: 0.51318
# Epoch: 22, Iteration: 160/200, Loss: 0.96249, IoU: 0.48933
# Epoch: 22, Iteration: 170/200, Loss: 0.95016, IoU: 0.51375
# Epoch: 22, Iteration: 180/200, Loss: 0.93483, IoU: 0.51247
# Epoch: 22, Iteration: 190/200, Loss: 0.94451, IoU: 0.49295
# Epoch: 23, Iteration: 0/200, Loss: 0.94906, IoU: 0.47046
# Epoch: 23, Iteration: 10/200, Loss: 0.92875, IoU: 0.48780
# Epoch: 23, Iteration: 20/200, Loss: 0.93843, IoU: 0.47041
# Epoch: 23, Iteration: 30/200, Loss: 0.93998, IoU: 0.48928
# Epoch: 23, Iteration: 40/200, Loss: 0.92997, IoU: 0.50017
# Epoch: 23, Iteration: 50/200, Loss: 0.90736, IoU: 0.50543
# Epoch: 23, Iteration: 60/200, Loss: 0.92383, IoU: 0.48650
# Epoch: 23, Iteration: 70/200, Loss: 0.95294, IoU: 0.46883
# Epoch: 23, Iteration: 80/200, Loss: 0.95009, IoU: 0.47175
# Epoch: 23, Iteration: 90/200, Loss: 0.90840, IoU: 0.50736
# Epoch: 23, Iteration: 100/200, Loss: 0.92722, IoU: 0.47991
# Epoch: 23, Iteration: 110/200, Loss: 0.97364, IoU: 0.45746
# Epoch: 23, Iteration: 120/200, Loss: 0.93940, IoU: 0.48125
# Epoch: 23, Iteration: 130/200, Loss: 0.92205, IoU: 0.46345
# Epoch: 23, Iteration: 140/200, Loss: 0.89450, IoU: 0.50649
# Epoch: 23, Iteration: 150/200, Loss: 0.91665, IoU: 0.47880
# Epoch: 23, Iteration: 160/200, Loss: 0.92647, IoU: 0.50443
# Epoch: 23, Iteration: 170/200, Loss: 0.93880, IoU: 0.49987
# Epoch: 23, Iteration: 180/200, Loss: 0.97054, IoU: 0.47256
# Epoch: 23, Iteration: 190/200, Loss: 0.93266, IoU: 0.50316
# Epoch: 24, Iteration: 0/200, Loss: 0.93255, IoU: 0.49409
# Epoch: 24, Iteration: 10/200, Loss: 0.95493, IoU: 0.53352
# Epoch: 24, Iteration: 20/200, Loss: 0.91066, IoU: 0.49561
# Epoch: 24, Iteration: 30/200, Loss: 0.94819, IoU: 0.51829
# Epoch: 24, Iteration: 40/200, Loss: 0.93877, IoU: 0.48911
# Epoch: 24, Iteration: 50/200, Loss: 0.91924, IoU: 0.49914
# Epoch: 24, Iteration: 60/200, Loss: 0.92623, IoU: 0.50672
# Epoch: 24, Iteration: 70/200, Loss: 0.90637, IoU: 0.46363
# Epoch: 24, Iteration: 80/200, Loss: 0.91495, IoU: 0.48097
# Epoch: 24, Iteration: 90/200, Loss: 0.91943, IoU: 0.49298
# Epoch: 24, Iteration: 100/200, Loss: 0.91711, IoU: 0.48349
# Epoch: 24, Iteration: 110/200, Loss: 0.93333, IoU: 0.49383
# Epoch: 24, Iteration: 120/200, Loss: 0.93929, IoU: 0.49203
# Epoch: 24, Iteration: 130/200, Loss: 0.97247, IoU: 0.48047
# Epoch: 24, Iteration: 140/200, Loss: 0.95204, IoU: 0.51279
# Epoch: 24, Iteration: 150/200, Loss: 0.94967, IoU: 0.47101
# Epoch: 24, Iteration: 160/200, Loss: 0.93726, IoU: 0.50452
# Epoch: 24, Iteration: 170/200, Loss: 0.93913, IoU: 0.46171
# Epoch: 24, Iteration: 180/200, Loss: 0.91569, IoU: 0.47020
# Epoch: 24, Iteration: 190/200, Loss: 0.91567, IoU: 0.48751
# Epoch: 25, Iteration: 0/200, Loss: 0.92987, IoU: 0.49893
# Epoch: 25, Iteration: 10/200, Loss: 0.92206, IoU: 0.47359
# Epoch: 25, Iteration: 20/200, Loss: 0.92615, IoU: 0.49441
# Min loss 0.88559
# Epoch: 25, Iteration: 30/200, Loss: 0.90942, IoU: 0.49299
# Epoch: 25, Iteration: 40/200, Loss: 0.93815, IoU: 0.49873
# Epoch: 25, Iteration: 50/200, Loss: 0.94363, IoU: 0.52529
# Epoch: 25, Iteration: 60/200, Loss: 0.96680, IoU: 0.49639
# Epoch: 25, Iteration: 70/200, Loss: 0.95532, IoU: 0.49822
# Epoch: 25, Iteration: 80/200, Loss: 0.95099, IoU: 0.48580
# Epoch: 25, Iteration: 90/200, Loss: 0.93183, IoU: 0.50419
# Epoch: 25, Iteration: 100/200, Loss: 0.91470, IoU: 0.47902
# Epoch: 25, Iteration: 110/200, Loss: 0.93395, IoU: 0.47373
# Epoch: 25, Iteration: 120/200, Loss: 0.91673, IoU: 0.45888
# Epoch: 25, Iteration: 130/200, Loss: 0.94045, IoU: 0.49279
# Epoch: 25, Iteration: 140/200, Loss: 0.92681, IoU: 0.47197
# Epoch: 25, Iteration: 150/200, Loss: 0.89656, IoU: 0.52391
# Epoch: 25, Iteration: 160/200, Loss: 0.93643, IoU: 0.50265
# Epoch: 25, Iteration: 170/200, Loss: 0.91651, IoU: 0.51105
# Epoch: 25, Iteration: 180/200, Loss: 0.93267, IoU: 0.49670
# Epoch: 25, Iteration: 190/200, Loss: 0.93285, IoU: 0.49958
# Epoch: 26, Iteration: 0/200, Loss: 0.93125, IoU: 0.48261
# Epoch: 26, Iteration: 10/200, Loss: 0.93929, IoU: 0.49537
# Epoch: 26, Iteration: 20/200, Loss: 0.90177, IoU: 0.49322
# Epoch: 26, Iteration: 30/200, Loss: 0.92104, IoU: 0.50836
# Min loss 0.87852
# Epoch: 26, Iteration: 40/200, Loss: 0.93394, IoU: 0.50233
# Epoch: 26, Iteration: 50/200, Loss: 0.90069, IoU: 0.44684
# Epoch: 26, Iteration: 60/200, Loss: 0.96493, IoU: 0.49528
# Epoch: 26, Iteration: 70/200, Loss: 0.91780, IoU: 0.47624
# Epoch: 26, Iteration: 80/200, Loss: 0.95028, IoU: 0.46392
# Epoch: 26, Iteration: 90/200, Loss: 0.91967, IoU: 0.45954
# Epoch: 26, Iteration: 100/200, Loss: 0.93700, IoU: 0.48690
# Epoch: 26, Iteration: 110/200, Loss: 0.88781, IoU: 0.49536
# Epoch: 26, Iteration: 120/200, Loss: 0.92993, IoU: 0.49757
# Epoch: 26, Iteration: 130/200, Loss: 0.91617, IoU: 0.46654
# Epoch: 26, Iteration: 140/200, Loss: 0.94181, IoU: 0.48077
# Epoch: 26, Iteration: 150/200, Loss: 0.90888, IoU: 0.47801
# Epoch: 26, Iteration: 160/200, Loss: 0.94742, IoU: 0.48634
# Epoch: 26, Iteration: 170/200, Loss: 0.91234, IoU: 0.48283
# Epoch: 26, Iteration: 180/200, Loss: 0.92141, IoU: 0.46185
# Epoch: 26, Iteration: 190/200, Loss: 0.91662, IoU: 0.50894
# Epoch: 27, Iteration: 0/200, Loss: 0.91558, IoU: 0.49860
# Epoch: 27, Iteration: 10/200, Loss: 0.93722, IoU: 0.51653
# Epoch: 27, Iteration: 20/200, Loss: 0.92537, IoU: 0.48095
# Epoch: 27, Iteration: 30/200, Loss: 0.90900, IoU: 0.50739
# Epoch: 27, Iteration: 40/200, Loss: 0.92142, IoU: 0.50420
# Epoch: 27, Iteration: 50/200, Loss: 0.94733, IoU: 0.47358
# Epoch: 27, Iteration: 60/200, Loss: 0.89640, IoU: 0.50320
# Epoch: 27, Iteration: 70/200, Loss: 0.93303, IoU: 0.46219
# Epoch: 27, Iteration: 80/200, Loss: 0.94507, IoU: 0.47450
# Epoch: 27, Iteration: 90/200, Loss: 0.89567, IoU: 0.48584
# Epoch: 27, Iteration: 100/200, Loss: 0.93346, IoU: 0.54308
# Epoch: 27, Iteration: 110/200, Loss: 0.88400, IoU: 0.44967
# Epoch: 27, Iteration: 120/200, Loss: 0.92523, IoU: 0.46656
# Epoch: 27, Iteration: 130/200, Loss: 0.94093, IoU: 0.49799
# Epoch: 27, Iteration: 140/200, Loss: 0.90668, IoU: 0.49388
# Epoch: 27, Iteration: 150/200, Loss: 0.92244, IoU: 0.47714
# Epoch: 27, Iteration: 160/200, Loss: 0.91572, IoU: 0.50749
# Epoch: 27, Iteration: 170/200, Loss: 0.90818, IoU: 0.42867
# Epoch: 27, Iteration: 180/200, Loss: 0.91042, IoU: 0.48503
# Epoch: 27, Iteration: 190/200, Loss: 0.93482, IoU: 0.47038
# Epoch: 28, Iteration: 0/200, Loss: 0.94013, IoU: 0.45238
# Epoch: 28, Iteration: 10/200, Loss: 0.90682, IoU: 0.48393
# Epoch: 28, Iteration: 20/200, Loss: 0.92001, IoU: 0.50318
# Epoch: 28, Iteration: 30/200, Loss: 0.93428, IoU: 0.52400
# Epoch: 28, Iteration: 40/200, Loss: 0.92964, IoU: 0.46310
# Epoch: 28, Iteration: 50/200, Loss: 0.91319, IoU: 0.47039
# Min loss 0.87753
# Epoch: 28, Iteration: 60/200, Loss: 0.90290, IoU: 0.47973
# Epoch: 28, Iteration: 70/200, Loss: 0.93419, IoU: 0.45880
# Epoch: 28, Iteration: 80/200, Loss: 0.90292, IoU: 0.46743
# Epoch: 28, Iteration: 90/200, Loss: 0.95141, IoU: 0.45934
# Epoch: 28, Iteration: 100/200, Loss: 0.92035, IoU: 0.50797
# Epoch: 28, Iteration: 110/200, Loss: 0.89027, IoU: 0.45411
# Epoch: 28, Iteration: 120/200, Loss: 0.95292, IoU: 0.45903
# Epoch: 28, Iteration: 130/200, Loss: 0.92571, IoU: 0.49723
# Epoch: 28, Iteration: 140/200, Loss: 0.90970, IoU: 0.47225
# Epoch: 28, Iteration: 150/200, Loss: 0.93169, IoU: 0.48989
# Epoch: 28, Iteration: 160/200, Loss: 0.91527, IoU: 0.47755
# Epoch: 28, Iteration: 170/200, Loss: 0.94076, IoU: 0.49268
# Epoch: 28, Iteration: 180/200, Loss: 0.90441, IoU: 0.47997
# Epoch: 28, Iteration: 190/200, Loss: 0.94100, IoU: 0.46757
# Epoch: 29, Iteration: 0/200, Loss: 0.95572, IoU: 0.49609
# Epoch: 29, Iteration: 10/200, Loss: 0.92874, IoU: 0.49791
# Epoch: 29, Iteration: 20/200, Loss: 0.89274, IoU: 0.48709
# Epoch: 29, Iteration: 30/200, Loss: 0.88574, IoU: 0.47478
# Min loss 0.87657
# Epoch: 29, Iteration: 40/200, Loss: 0.92308, IoU: 0.53804
# Epoch: 29, Iteration: 50/200, Loss: 0.91429, IoU: 0.46121
# Epoch: 29, Iteration: 60/200, Loss: 0.93084, IoU: 0.47515
# Epoch: 29, Iteration: 70/200, Loss: 0.89404, IoU: 0.49051
# Epoch: 29, Iteration: 80/200, Loss: 0.90259, IoU: 0.47930
# Epoch: 29, Iteration: 90/200, Loss: 0.90261, IoU: 0.49675
# Epoch: 29, Iteration: 100/200, Loss: 0.90234, IoU: 0.49665
# Epoch: 29, Iteration: 110/200, Loss: 0.92772, IoU: 0.50846
# Epoch: 29, Iteration: 120/200, Loss: 0.92503, IoU: 0.49145
# Epoch: 29, Iteration: 130/200, Loss: 0.90919, IoU: 0.49814
# Epoch: 29, Iteration: 140/200, Loss: 0.89543, IoU: 0.47660
# Epoch: 29, Iteration: 150/200, Loss: 0.89871, IoU: 0.49690
# Epoch: 29, Iteration: 160/200, Loss: 0.89222, IoU: 0.49459
# Min loss 0.86654
# Epoch: 29, Iteration: 170/200, Loss: 0.90849, IoU: 0.51013
# Epoch: 29, Iteration: 180/200, Loss: 0.89065, IoU: 0.50615
# Epoch: 29, Iteration: 190/200, Loss: 0.89844, IoU: 0.52587
# Epoch: 30, Iteration: 0/200, Loss: 0.89481, IoU: 0.50953
# Epoch: 30, Iteration: 10/200, Loss: 0.95098, IoU: 0.49384
# Epoch: 30, Iteration: 20/200, Loss: 0.89342, IoU: 0.51091
# Epoch: 30, Iteration: 30/200, Loss: 0.92266, IoU: 0.51379
# Epoch: 30, Iteration: 40/200, Loss: 0.90618, IoU: 0.48927
# Epoch: 30, Iteration: 50/200, Loss: 0.90246, IoU: 0.49612
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:26
#
# File c:\Users\lenovo\Desktop\burak\ECE176\assignment6\.venv\Lib\site-packages\torch\_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File c:\Users\lenovo\Desktop\burak\ECE176\assignment6\.venv\Lib\site-packages\torch\autograd\__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:

# %%
plt.plot(loss_epoch_arr)
plt.show()

# %%
model.load_state_dict(best_model)
# Out:
# <All keys matched successfully>

# %%
print(model)
# Out:
# InpaintingModel(
#   (encoder_1): EncoderLayer(
#     (p_conv_1): PartialConv(
#       (input_conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mask_conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (bn_1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act_1): ReLU()
#     (p_conv_2): PartialConv(
#       (input_conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (mask_conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     )
#     (bn_2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act_2): ReLU()
#   )
#   (encoder_2): EncoderLayer(
#     (p_conv_1): PartialConv(
#       (input_conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mask_conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (bn_1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act_1): ReLU()
#     (p_conv_2): PartialConv(
#       (input_conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (mask_conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     )
#     (bn_2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act_2): ReLU()
#   )
#   (encoder_3): EncoderLayer(
#     (p_conv_1): PartialConv(
#       (input_conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mask_conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (bn_1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act_1): ReLU()
#     (p_conv_2): PartialConv(
#       (input_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (mask_conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     )
#     (bn_2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act_2): ReLU()
#   )
#   (encoder_4): EncoderLayer(
#     (p_conv_1): PartialConv(
#       (input_conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mask_conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (bn_1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act_1): ReLU()
#     (p_conv_2): PartialConv(
#       (input_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#       (mask_conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     )
#     (bn_2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act_2): ReLU()
#   )
#   (decoder_1): DecoderLayer(
#     (up_image): Upsample(scale_factor=(2.0, 2.0), mode='nearest')
#     (up_mask): Upsample(scale_factor=(2.0, 2.0), mode='nearest')
#     (p_conv_1): PartialConv(
#       (input_conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mask_conv): Conv2d(512, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (bn_1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act_1): LeakyReLU(negative_slope=0.2)
#     (p_conv_2): PartialConv(
#       (input_conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mask_conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (bn_2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act_2): LeakyReLU(negative_slope=0.2)
#   )
#   (decoder_2): DecoderLayer(
#     (up_image): Upsample(scale_factor=(2.0, 2.0), mode='nearest')
#     (up_mask): Upsample(scale_factor=(2.0, 2.0), mode='nearest')
#     (p_conv_1): PartialConv(
#       (input_conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mask_conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (bn_1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act_1): LeakyReLU(negative_slope=0.2)
#     (p_conv_2): PartialConv(
#       (input_conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mask_conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (bn_2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act_2): LeakyReLU(negative_slope=0.2)
#   )
#   (decoder_3): DecoderLayer(
#     (up_image): Upsample(scale_factor=(2.0, 2.0), mode='nearest')
#     (up_mask): Upsample(scale_factor=(2.0, 2.0), mode='nearest')
#     (p_conv_1): PartialConv(
#       (input_conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mask_conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (bn_1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act_1): LeakyReLU(negative_slope=0.2)
#     (p_conv_2): PartialConv(
#       (input_conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mask_conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (bn_2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act_2): LeakyReLU(negative_slope=0.2)
#   )
#   (decoder_4): DecoderLayer(
#     (up_image): Upsample(scale_factor=(2.0, 2.0), mode='nearest')
#     (up_mask): Upsample(scale_factor=(2.0, 2.0), mode='nearest')
#     (p_conv_1): PartialConv(
#       (input_conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mask_conv): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (bn_1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act_1): LeakyReLU(negative_slope=0.2)
#     (p_conv_2): PartialConv(
#       (input_conv): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (mask_conv): Conv2d(32, 3, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (bn_2): BatchNorm2d(3, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (act_2): LeakyReLU(negative_slope=0.2)
#   )
#   (output_layer): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     (3): Conv2d(64, 128, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): LeakyReLU(negative_slope=0.2, inplace=True)
#     (6): Conv2d(128, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): LeakyReLU(negative_slope=0.2, inplace=True)
#     (9): Conv2d(256, 3, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (10): Sigmoid()
#   )
# )

# %%
torch.save(model.state_dict(), './model_celebA_2.pt')

# %% [markdown]
# # **Results**

# %%
sample_inputs, sample_masks, sample_truths = next(Train_dataiter)
sample_inputs, sample_masks = sample_inputs.cuda(), sample_masks.cuda()

model.eval()
with torch.no_grad():
    sample_preds = model(sample_inputs, sample_masks)

fig, axs = plt.subplots(nrows=4, ncols=4, figsize=(8, 8))

for i in range(4):
    axs[i][0].imshow(np.transpose(sample_truths[i], (1, 2, 0)))
    axs[i][0].axis('off')
    axs[i][1].imshow(np.transpose(sample_masks[i].cpu(), (1, 2, 0)))
    axs[i][1].axis('off')
    axs[i][2].imshow(np.transpose(sample_inputs[i].cpu(),(1, 2, 0)))
    axs[i][2].axis('off')
    axs[i][3].imshow(np.transpose(sample_preds[i].cpu(), (1, 2, 0)))
    axs[i][3].axis('off')
plt.show()

# %%
sample_inputs, sample_masks, sample_truths = next(Test_dataiter)
sample_inputs, sample_masks = sample_inputs.cuda(), sample_masks.cuda()

model.eval()
with torch.no_grad():
    sample_preds = model(sample_inputs, sample_masks)

fig, axs = plt.subplots(nrows=4, ncols=4, figsize=(8, 8))

for i in range(4):
    axs[i][0].imshow(np.transpose(sample_truths[i], (1, 2, 0)))
    axs[i][0].axis('off')
    axs[i][1].imshow(np.transpose(sample_masks[i].cpu(), (1, 2, 0)))
    axs[i][1].axis('off')
    axs[i][2].imshow(np.transpose(sample_inputs[i].cpu(),(1, 2, 0)))
    axs[i][2].axis('off')
    axs[i][3].imshow(np.transpose(sample_preds[i].cpu(), (1, 2, 0)))
    axs[i][3].axis('off')
plt.show()

# %%
# Call this to download the model weights
"""
model = InpaintingModel()
model = model.to(device)
model.load_state_dict(torch.load('./model.pt'))
model.eval()
"""
# Out:
# "\nmodel = InpaintingModel()\nmodel.load_state_dict(torch.load('./model.pt'))\nmodel.eval()\n"
